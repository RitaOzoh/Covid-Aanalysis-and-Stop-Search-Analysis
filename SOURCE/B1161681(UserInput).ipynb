# %%
user_input = 'Nothing'
while user_input != 'covid'.lower() or user_input != 's&s'.lower():
    user_input = input('Enter "Covid" to run covid analysis or "S&S" to run stop and search analysis: ')
    user_input = user_input.lower()

    if user_input == 'covid'.lower():
        # %run B1161681(COVID).ipynb
    
    elif user_input =='s&s'.lower():
        # %run B1161681(Stop&Search).ipynb
# Out:
# Enter "Covid" to run covid analysis or "S&S" to run stop and search analysis:  covid
# ****Required Libraries loaded****
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\OneDrive - Teesside University\2021 SESSION (SEMESTER 1)\Software for Digital Innovation\ICA\Part 2\B1161681_OZOH_RITA\SOURCE\B1161681(COVID).ipynb in <module>
# ----> 1 data = df_preprocess()
#       2
#       3 #date_report_display(freq, from_date, to_date)
#       4
#       5 date_report_display(df=data, freq='daily', from_date='2020-02-02', to_date='2020-02-15')
#
# ~\OneDrive - Teesside University\2021 SESSION (SEMESTER 1)\Software for Digital Innovation\ICA\Part 2\B1161681_OZOH_RITA\SOURCE\B1161681(COVID).ipynb in df_preprocess()
#      10
#      11     print('****Required Libraries loaded****')
# ---> 12     df_main = pd.read_csv("specimenDate_ageDemographic-unstacked.csv", parse_dates = ["date"])
# ...
